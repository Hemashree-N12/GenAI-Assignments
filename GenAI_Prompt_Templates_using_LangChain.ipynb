# %% [markdown]
# # Assignment 1: Mastering Prompt Templates in LangChain

# %% [markdown]
# # Objective
#  Build dynamic and reusable prompt systems using LangChain instead of hardcoded prompts.

# %% [markdown]
# ## Install Langchain

# %%
# !pip install langchain
# Out:
# Collecting langchain
#   Downloading langchain-1.2.15-py3-none-any.whl.metadata (5.8 kB)
# Collecting langchain-core<2.0.0,>=1.2.10 (from langchain)
#   Downloading langchain_core-1.2.28-py3-none-any.whl.metadata (4.4 kB)
# Collecting langgraph<1.2.0,>=1.1.5 (from langchain)
#   Downloading langgraph-1.1.6-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in .\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain) (2.12.5)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading langsmith-0.7.30-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=23.2.0 in .\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in .\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in .\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in .\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading uuid_utils-0.14.1-cp39-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: jsonpointer>=1.9 in .\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Collecting langgraph-checkpoint<5.0.0,>=2.1.0 (from langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading langgraph_checkpoint-4.0.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.9 (from langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading langgraph_prebuilt-1.0.9-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading langgraph_sdk-0.3.13-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: xxhash>=3.5.0 in .\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading ormsgpack-1.12.2-cp311-cp311-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: httpx>=0.25.2 in .\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.28.1)
# Collecting orjson>=3.11.5 (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading orjson-3.11.8-cp311-cp311-win_amd64.whl.metadata (43 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.0.0 in .\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.5)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading zstandard-0.25.0-cp311-cp311-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: anyio in .\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (4.12.1)
# Requirement already satisfied: certifi in .\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in .\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: idna in .\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in .\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in .\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in .\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.5.0)
# Downloading langchain-1.2.15-py3-none-any.whl (112 kB)
# Downloading langchain_core-1.2.28-py3-none-any.whl (508 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langgraph-1.1.6-py3-none-any.whl (169 kB)
# Downloading langgraph_checkpoint-4.0.1-py3-none-any.whl (50 kB)
# Downloading langgraph_prebuilt-1.0.9-py3-none-any.whl (35 kB)
# Downloading langgraph_sdk-0.3.13-py3-none-any.whl (96 kB)
# Downloading langsmith-0.7.30-py3-none-any.whl (372 kB)
# Downloading uuid_utils-0.14.1-cp39-abi3-win_amd64.whl (187 kB)
# Downloading orjson-3.11.8-cp311-cp311-win_amd64.whl (127 kB)
# Downloading ormsgpack-1.12.2-cp311-cp311-win_amd64.whl (117 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading zstandard-0.25.0-cp311-cp311-win_amd64.whl (506 kB)
# Installing collected packages: zstandard, uuid-utils, ormsgpack, orjson, jsonpatch, requests-toolbelt, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langgraph-prebuilt, langgraph, langchain
#
#    ----------------------------------------  0/13 [zstandard]
#    --- ------------------------------------  1/13 [uuid-utils]
#    --------- ------------------------------  3/13 [orjson]
#    ------------ ---------------------------  4/13 [jsonpatch]
#    --------------- ------------------------  5/13 [requests-toolbelt]
#    --------------- ------------------------  5/13 [requests-toolbelt]
#    --------------- ------------------------  5/13 [requests-toolbelt]
#    --------------- ------------------------  5/13 [requests-toolbelt]
#    --------------- ------------------------  5/13 [requests-toolbelt]
#    --------------- ------------------------  5/13 [requests-toolbelt]
#    --------------- ------------------------  5/13 [requests-toolbelt]
#    ------------------ ---------------------  6/13 [langsmith]
#    ------------------ ---------------------  6/13 [langsmith]
#    ------------------ ---------------------  6/13 [langsmith]
#    ------------------ ---------------------  6/13 [langsmith]
#    ------------------ ---------------------  6/13 [langsmith]
#    ------------------ ---------------------  6/13 [langsmith]
#    ------------------ ---------------------  6/13 [langsmith]
#    ------------------ ---------------------  6/13 [langsmith]
#    ------------------ ---------------------  6/13 [langsmith]
#    ------------------ ---------------------  6/13 [langsmith]
#    ------------------ ---------------------  6/13 [langsmith]
#    ------------------ ---------------------  6/13 [langsmith]
#    ------------------ ---------------------  6/13 [langsmith]
#    ------------------ ---------------------  6/13 [langsmith]
#    ------------------ ---------------------  6/13 [langsmith]
#    ------------------ ---------------------  6/13 [langsmith]
#    ------------------ ---------------------  6/13 [langsmith]
#    ------------------ ---------------------  6/13 [langsmith]
#    ------------------ ---------------------  6/13 [langsmith]
#    ------------------ ---------------------  6/13 [langsmith]
#    ------------------ ---------------------  6/13 [langsmith]
#    ------------------ ---------------------  6/13 [langsmith]
#    ------------------ ---------------------  6/13 [langsmith]
#    --------------------- ------------------  7/13 [langgraph-sdk]
#    --------------------- ------------------  7/13 [langgraph-sdk]
#    --------------------- ------------------  7/13 [langgraph-sdk]
#    --------------------- ------------------  7/13 [langgraph-sdk]
#    --------------------- ------------------  7/13 [langgraph-sdk]
#    --------------------- ------------------  7/13 [langgraph-sdk]
#    --------------------- ------------------  7/13 [langgraph-sdk]
#    --------------------- ------------------  7/13 [langgraph-sdk]
#    --------------------- ------------------  7/13 [langgraph-sdk]
#    --------------------- ------------------  7/13 [langgraph-sdk]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    ------------------------ ---------------  8/13 [langchain-core]
#    --------------------------- ------------  9/13 [langgraph-checkpoint]
#    --------------------------- ------------  9/13 [langgraph-checkpoint]
#    --------------------------- ------------  9/13 [langgraph-checkpoint]
#    --------------------------- ------------  9/13 [langgraph-checkpoint]
#    --------------------------- ------------  9/13 [langgraph-checkpoint]
#    --------------------------- ------------  9/13 [langgraph-checkpoint]
#    ------------------------------ --------- 10/13 [langgraph-prebuilt]
#    --------------------------------- ------ 11/13 [langgraph]
#    --------------------------------- ------ 11/13 [langgraph]
#    --------------------------------- ------ 11/13 [langgraph]
#    --------------------------------- ------ 11/13 [langgraph]
#    --------------------------------- ------ 11/13 [langgraph]
#    --------------------------------- ------ 11/13 [langgraph]
#    --------------------------------- ------ 11/13 [langgraph]
#    --------------------------------- ------ 11/13 [langgraph]
#    --------------------------------- ------ 11/13 [langgraph]
#    --------------------------------- ------ 11/13 [langgraph]
#    --------------------------------- ------ 11/13 [langgraph]
#    --------------------------------- ------ 11/13 [langgraph]
#    --------------------------------- ------ 11/13 [langgraph]
#    --------------------------------- ------ 11/13 [langgraph]
#    --------------------------------- ------ 11/13 [langgraph]
#    --------------------------------- ------ 11/13 [langgraph]
#    --------------------------------- ------ 11/13 [langgraph]
#    ------------------------------------ --- 12/13 [langchain]
#    ------------------------------------ --- 12/13 [langchain]
#    ------------------------------------ --- 12/13 [langchain]
#    ------------------------------------ --- 12/13 [langchain]
#    ------------------------------------ --- 12/13 [langchain]
#    ------------------------------------ --- 12/13 [langchain]
#    ---------------------------------------- 13/13 [langchain]
#
# Successfully installed jsonpatch-1.33 langchain-1.2.15 langchain-core-1.2.28 langgraph-1.1.6 langgraph-checkpoint-4.0.1 langgraph-prebuilt-1.0.9 langgraph-sdk-0.3.13 langsmith-0.7.30 orjson-3.11.8 ormsgpack-1.12.2 requests-toolbelt-1.0.0 uuid-utils-0.14.1 zstandard-0.25.0

# %% [markdown]
# ## Task 1: Replace Hardcoded Prompts

# %%
# Given Code
def explain_topic(topic):
   return f"Explain {topic} in simple terms for beginners"

# %%
from langchain_core.prompts import PromptTemplate

# Define reusable template (No f string)
explain_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms for beginners"
)

# Example usage
print(explain_template.format(topic="Generative AI"))
# Out:
# Explain Generative AI in simple terms for beginners

# %% [markdown]
# ## Task 2: Multi-Input Prompt System

# %%
multi_template = PromptTemplate(
    input_variables=["topic", "audience", "tone"],
    template="Explain {topic} for {audience} in a {tone} tone"
)

# Test cases
print(multi_template.format(topic="AI", audience="beginners", tone="friendly"))
print(multi_template.format(topic="Python", audience="kids", tone="fun"))
print(multi_template.format(topic="Deep Learning", audience="engineers", tone="technical"))
# Out:
# Explain AI for beginners in a friendly tone
# Explain Python for kids in a fun tone
# Explain Deep Learning for engineers in a technical tone

# %% [markdown]
# ## Task 3: Prompt Variations Engine

# %%
teaching_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} clearly step by step"
)

interview_template = PromptTemplate(
    input_variables=["topic"],
    template="Ask 3 questions about {topic}"
)

story_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} as a story"
)

topic = "Machine Learning"
print(teaching_template.format(topic=topic))
print(interview_template.format(topic=topic))
print(story_template.format(topic=topic))
# Out:
# Explain Machine Learning clearly step by step
# Ask 3 questions about Machine Learning
# Explain Machine Learning as a story

# %% [markdown]
# ## Task 4: Chat PromptTemplate System

# %%
from langchain_core.prompts import ChatPromptTemplate

# Define the chat template
chat_template = ChatPromptTemplate.from_messages([
    ("system", "You are a {role}. Respond thoughtfully and clearly."),
    ("user", "Explain the concept of {topic} in your own style.")
])

# Example roles and topic
roles = ["teacher", "interviewer", "motivator"]
topic = "Neural Networks"

# Generate formatted prompts for each role
for role in roles:
    formatted_prompt = chat_template.format(role=role, topic=topic)
    print("\n--- Role:", role.upper(), "---")
    print(formatted_prompt)
# Out:
# --- Role: TEACHER ---
# System: You are a teacher. Respond thoughtfully and clearly.
# Human: Explain the concept of Neural Networks in your own style.
#
# --- Role: INTERVIEWER ---
# System: You are a interviewer. Respond thoughtfully and clearly.
# Human: Explain the concept of Neural Networks in your own style.
#
# --- Role: MOTIVATOR ---
# System: You are a motivator. Respond thoughtfully and clearly.
# Human: Explain the concept of Neural Networks in your own style.

# %% [markdown]
# ## Task 5: Input Validation Layer

# %%
def validate_inputs(audience, tone):
    valid_audience = ["beginner", "intermediate", "expert"]
    valid_tone = ["formal", "casual", "fun"]

    # Validate audience
    if audience not in valid_audience:
        print("Invalid audience! Defaulting to 'beginner'.")
        audience = "beginner"

    # Validate tone
    if tone not in valid_tone:
        print("Invalid tone! Defaulting to 'formal'.")
        tone = "formal"

    return audience, tone

# Example test
print(validate_inputs("intermediate", "casual"))
print(validate_inputs("expert", "formal"))
print(validate_inputs("expert", "happy"))
print(validate_inputs("kids", "fun"))
# Out:
# ('intermediate', 'casual')
# ('expert', 'formal')
# Invalid tone! Defaulting to 'formal'.
# ('expert', 'formal')
# Invalid audience! Defaulting to 'beginner'.
# ('beginner', 'fun')

# %% [markdown]
# ## Task 6: Prompt Generator App

# %%
def generate_prompt(topic, audience, tone, style):
    audience, tone = validate_inputs(audience, tone)

    if style == "teaching":
        template = PromptTemplate(
            input_variables=["topic", "audience", "tone"],
            template="Explain {topic} for {audience} in a {tone} teaching style"
        )
    elif style == "interview":
        template = PromptTemplate(
            input_variables=["topic"],
            template="Ask 3 interview questions about {topic}"
        )
    elif style == "storytelling":
        template = PromptTemplate(
            input_variables=["topic", "audience", "tone"],
            template="Explain {topic} for a {audience} in a {tone} storytelling style"
        )
    else:
        raise ValueError("Invalid style")

    return template.format(topic=topic, audience=audience, tone=tone)

print(generate_prompt("Neural Networks", "beginner", "fun", "storytelling"))
# Out:
# Explain Neural Networks for a beginner in a fun storytelling style

# %% [markdown]
# ## Task 7: Template Reusability Test

# %%
#building a reuseable prompt template
reusable_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in a very simple manner for a begginer to understand easily."
)

topics = ["AI", "Python", "Data Science", "Deep Learning", "NLP", "Generative AI"]

#Reusing the template for differant instances
for t in topics:
    print(reusable_template.format(topic=t))
# Out:
# Explain AI in a very simple manner for a begginer to understand easily.
# Explain Python in a very simple manner for a begginer to understand easily.
# Explain Data Science in a very simple manner for a begginer to understand easily.
# Explain Deep Learning in a very simple manner for a begginer to understand easily.
# Explain NLP in a very simple manner for a begginer to understand easily.
# Explain Generative AI in a very simple manner for a begginer to understand easily.
